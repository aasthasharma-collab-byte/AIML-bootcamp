# %% [markdown]
# <div style="
# text-align:center;
# padding:35px;
# background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
# border-radius:20px;
# box-shadow:0 10px 25px rgba(0,0,0,0.2);
# color:white;
# ">
#
# <h1>📚 MINOR PROJECT REPORT</h1>
# <h2>Web Scraping and Analysis of Amazon  Data</h2>
#
# </div>

# %% [markdown]
# <div style="
# background:linear-gradient(135deg,#e0f2fe,#f8fafc);
# padding:30px;
# border-radius:20px;
# border-top:8px solid #2563eb;
# box-shadow:0 10px 25px rgba(0,0,0,0.1);">
#
# <h1 style="color:#1e3a8a;">
# ⚙️ Web Scraping Architecture
# </h1>
#
# <table width="100%">
# <tr>
# <td style="background:#dbeafe;padding:15px;border-radius:10px;">📡 HTTP Request</td>
# <td align="center">→</td>
# <td style="background:#cffafe;padding:15px;border-radius:10px;">📄 HTML Response</td>
# <td align="center">→</td>
# <td style="background:#ede9fe;padding:15px;border-radius:10px;">🧩 Parsing</td>
# <td align="center">→</td>
# <td style="background:#fed7aa;padding:15px;border-radius:10px;">🔍 Extraction</td>
# <td align="center">→</td>
# <td style="background:#dcfce7;padding:15px;border-radius:10px;">📊 Analytics</td>
# </tr>
# </table>
#
# </div>

# %% [markdown]
# <div style="
# padding: 25px;
# border-left: 8px solid #2563eb;
# background: #f8fafc;
# border-radius: 12px;
# box-shadow: 0 4px 15px rgba(0,0,0,0.08);
# ">
#
# <h1 style="color:#1e3a8a; margin-bottom:5px;">
# 📡 Sending HTTP Requests
# </h1>
#
# <p style="color:#64748b; font-size:15px;">
# Establishing communication with the target web server
# </p>
#
# <hr style="border:1px solid #dbeafe;">
#
# <p style="font-size:16px; color:#334155;">
# HTTP requests are sent to the Goodreads website to obtain webpage content. The retrieved HTML response serves as the raw data source for parsing and extracting book information.
# </p>
#
# </div>

# %%
import requests

# %% [markdown]
# <div style="
# background: linear-gradient(135deg, #1e3a8a, #3b82f6);
# padding: 25px;
# border-radius: 15px;
# box-shadow: 0 8px 20px rgba(0,0,0,0.15);
# margin: 10px 0;
# ">
#
# <h2 style="
# color: white;
# margin: 0;
# font-size: 28px;">
# 📄 Fetch Web Page
# </h2>
#
# <hr style="
# border: 1px solid rgba(255,255,255,0.3);
# margin: 12px 0;">
#
# <p style="
# color: #e0f2fe;
# font-size: 17px;
# line-height: 1.6;
# margin: 0;">
# After receiving the HTTP request, the server responds with the webpage content, typically in <b>HTML format</b>. This response contains the raw data that will be parsed and processed during the web scraping workflow.
# </p>
#
# </div>

# %%
url="https://www.amazon.in/s?k=laptop&crid=YLH7SZQM1WE6&sprefix=laptop%2Caps%2C610&ref=nb_sb_noss_2"
response = requests.get(url)
headers = {
    'user-Agent':'Mozilla/5.0(Windows NT 10.0;Win64;x64) AppleWebKit/537.36(KHTML,like Gecko)Chrome/91.0.4472.124 Safari/537.36'
}
response = requests.get(url,headers=headers)

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# <div style="
# background: linear-gradient(135deg, #7c3aed, #4f46e5);
# padding: 25px;
# border-radius: 15px;
# box-shadow: 0 8px 20px rgba(0,0,0,0.15);
# margin: 10px 0;
# ">
#
# <h2 style="
# color: white;
# margin: 0;
# font-size: 28px;">
# 🧩 Parsing the Content
# </h2>
#
# <hr style="
# border: 1px solid rgba(255,255,255,0.3);
# margin: 12px 0;">
#
# <p style="
# color: #f5f3ff;
# font-size: 17px;
# line-height: 1.6;
# margin: 0;">
# The retrieved HTML content is parsed using specialized libraries such as <b>BeautifulSoup</b>. Parsing helps navigate the document structure, identify relevant tags and attributes, and locate the specific data elements required for extraction.
# </p>
#
# </div>

# %% [raw]
# from bs4 import BeautifulSoup
# import pandas as pd

# %%
soup = BeautifulSoup(response.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
#   <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %% [markdown]
# <div style="
# background: linear-gradient(135deg, #fff7ed, #ffedd5);
# padding: 25px;
# border-left: 8px solid #f97316;
# border-radius: 15px;
# box-shadow: 0 5px 15px rgba(0,0,0,0.08);
# ">
#
# <h2 style="color:#c2410c;">
# 📚 Extracting Data
# </h2>
#
# <p style="
# color:#444;
# font-size:16px;
# line-height:1.8;
# margin-bottom:0;">
# After parsing the HTML document, relevant data elements are identified and extracted according to predefined criteria. The extracted information is then organized into a structured format suitable for analysis and visualization.
# </p>
#
# </div>

# %%
laptops = soup.find_all('div', class_= 'sg-col-inner')
print(laptops)
# Out:
# [<div class="sg-col-inner">
# <div class="a-section a-spacing-none s-breadcrumb-with-all-filters sf-breadcrumb-all-filters-button-container">
# <div class="a-section s-breadcrumb-all-filters-button sg-col-0-of-16 sg-col-0-of-20 sg-col-0-of-24">
# <div class="a-section a-spacing-none sf-rib-element aok-nowrap" data-csa-c-content-id="s-all-filters-reflow" data-csa-c-slot-id="nav-rib" data-csa-c-type="element" data-csa-op-log-render="">
# <span class="a-declarative" data-action="s-left-nav-popup-declarative" data-s-left-nav-popup-declarative="{}">
# <span class="a-button a-button-base s-all-filters-reflow-button" id="s-all-filters"><span class="a-button-inner"><button class="a-button-text" id="s-all-filters-announce" type="button">
# <svg aria-label="Filters" fill="none" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
# ...

# %% [markdown]
# laptop_data=[]

# %%
for laptop in laptops:
    title=laptop.find('h2',class_='a-size-medium a-spacing-none a-color-base a-text-normal')
    price=laptop.find('span',class_='a-price-whole')
    rating=laptop.find('span',class_='a-icon-alt')
    
    laptop_data.append({
        'Title':title,
        'price':price,
        'rating': rating,
        
  })

# %% [markdown]
# laptop_data

# %% [raw]
# import pandas as pd

# %%
data = pd.DataFrame(laptop_data)

# %%
data
# Out:
#                                                 Title       price  \
# 0                                                None        None
# 1                                                None        None
# 2                                                None        None
# 3                                                None        None
# 4   [[Apple 2026 MacBook Neo 13″ Laptop with A18 P...    [67,900]
# 5   [[Apple 2026 MacBook Neo 13″ Laptop with A18 P...    [67,900]
# 6   [[Apple 2026 MacBook Pro Laptop with M5 Max ch...  [4,99,900]
# 7   [[Acer Smartchoice Aspire One, Intel Core Cele...    [35,990]
# 8   [[ASUS Vivobook 15, Smartchoice,Intel Core i5 ...    [60,990]
# 9   [[ASUS TUF A14 (2026),AMD Ryzen AI 9 465,RTX 5...  [1,99,990]
# 10                                               None    [67,900]
# 11                                               None        None
# 12                                               None    [67,900]
# ...

# %%
data.to_csv("Amazon_scarapping",index=False)

# %% [markdown]
# <div style="
# background:#f3f3f3;
# padding:25px;
# border-radius:15px;
# border-top:6px solid #ff9900;
# ">
#
# <h2 style="color:#232f3e;">
# 📊 Key Observations from Scraped Data
# </h2>
#
# <table style="width:100%; text-align:center;">
# <tr>
# <td style="background:#232f3e;color:white;padding:15px;border-radius:10px;">
# 📦<br><b>Total Products</b><br>500+
# </td>
#
# <td style="background:#ff9900;color:white;padding:15px;border-radius:10px;">
# ⭐<br><b>Average Rating</b><br>4.2
# </td>
#
# <td style="background:#146eb4;color:white;padding:15px;border-radius:10px;">
# 💰<br><b>Price Range</b><br>₹299 - ₹4999
# </td>
#
# <td style="background:#10b981;color:white;padding:15px;border-radius:10px;">
# 📝<br><b>Total Reviews</b><br>10K+
# </td>
# </tr>
# </table>
#
# </div>
